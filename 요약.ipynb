# %% [markdown]
# <a href="https://colab.research.google.com/github/dr-song-summer-project/ChatBot_NLP/blob/main/%EC%9A%94%EC%95%BD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.7/dist-packages (2.5.9)
# Requirement already satisfied: jdcal in /usr/local/lib/python3.7/dist-packages (from openpyxl) (1.4.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl) (1.1.0)

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-a626853c-d671-4198-9fc5-6a34ef954a0b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a626853c-d671-4198-9fc5-6a34ef954a0b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sampling.xlsx to sampling.xlsx

# %%
wb = Workbook()
sheet = wb.active
sheet.title = '분류된 문장' # 컬럼명 지정(헤더)

sheet.cell(row=1, column=1, value='인덱스')
sheet.cell(row=1, column=2, value='질문')
sheet.cell(row=1, column=3, value='질문 요약')
sheet.cell(row=1, column=4, value='답변')
sheet.cell(row=1, column=5, value='답변 요약')


wb.save('/content/sampling.xlsx')
wb.close()

# %%
# wb = openpyxl.load_workbook('/content/sampling.xlsx')
# sheet1 = wb.active

# print(sheet1.max_row)
# sheet1.delete_rows(19,20)
# print(sheet1.max_row)

# wb.save('/content/sampling.xlsx')
# wb.close()
# Out:
# 18

# %%
from collections import defaultdict
import nltk
import pandas as pd
import numpy as np
from openpyxl import Workbook
import openpyxl

MAXSIZE = 10
BREAKPOINT = True

# path_sample = 'src/sample_short.xlsx'
path_sample = '/content/newxlsx.xlsx'
# path_training = 'src/categories.xlsx'
test_path = '/content/test2.xlsx'  # 카테고리 항목

#엑셀 초기화
wb = openpyxl.load_workbook('/content/sampling.xlsx')
sheet1 = wb.active


def read_file(file_paths):  # ==파일 읽어오기
    df_ = pd.read_excel(file_paths)
    numpy = pd.DataFrame.to_numpy(df_)
    return df_, numpy


def classify(list_, text_Q, text_A):
    correct = True

    print('\n')
    print('질문 = '+text_Q)
    print('답변 = '+text_A)

    ant_Q = input("질문 요약문을 입력하세요 : ")
    #break
    if ant_Q == 'x': return BREAKPOINT
    ant_A = input("답변 요약문을 입력하세요 : ")
    while correct:
        select = (input('0~%d중 분류를 입력하세요 : ' % (len(list_) - 1)).split())
        for j in range(len(select)):
            if int(select[j]) < len(list_) and select[j] != '':
                correct = False
            else:
                correct = True

    index = " ".join(select)
    Idx.append(index)
    Query.append((text_Q, ant_Q))
    Answer.append((text_A, ant_A))
    #엑셀 append
    sheet1.append([index, text_Q, ant_Q, text_A, ant_A])

    wb.save('/content/sampling.xlsx')


# =============================================================

text_df, text_df_np = read_file(path_sample)  # 학습할 데이터
ct_df, ct_df_np = read_file(test_path)  # 데이터를 나눌 카테고리

# =============================================================

data = pd.DataFrame()
standard = pd.DataFrame()
data['querys'] = text_df['질문']
data['answers'] = text_df['답변']
standard['category3'] = ct_df['Category4']
# display(standard['category3'])

standard = standard[standard['category3'].notna()]
data = data[data['querys'].notna()]
data = data[data['answers'].notna()]
# category3 = [[0 for j in range(MAXSIZE)] for i in range(len(standard))]
category3 = []

# =============================================================

tmp = standard['category3'].values.tolist()
Qst = data['querys'].values.tolist()
Ans = data['answers'].values.tolist()

# =============================================================

Idx = []
Query = []
Answer = []

# =============================================================


#시작 인덱스
index = 2059

for i in range(index, len(data['querys'])):
    # category 출력
    for j in range(len(standard['category3'])):
        # category3[j] = tmp[j]
        print(j, '번: ', tmp[j], end=' ')
        if j % 6 == 0:
            print()
    # 코사인 유사도 측정 카테고리 출력
    # a = s.get_recommendation(str(Qst[i]))
    # 분류
    a = classify(tmp, Qst[i], Ans[i])
    print("last index : ", i)
    if a: 
      print("last index : ", i)
      break
    

# ============================================
# --  Excel 입력
# ============================================
# wb = Workbook()
# sheet = wb.active
# sheet.title = '분류된 문장' # 컬럼명 지정(헤더)

# sheet.cell(row=1, column=1, value='인덱스')
# sheet.cell(row=1, column=2, value='질문')
# sheet.cell(row=1, column=3, value='질문 요약')
# sheet.cell(row=1, column=4, value='답변')
# sheet.cell(row=1, column=5, value='답변 요약')


# # 시트 저장
# row_no = 2
# for n, rows in enumerate(Query):
#   for seq, value in enumerate(rows):
#     sheet.cell(row=row_no+n, column=1, value=Idx[n])
#     sheet.cell(row=row_no+n, column=2, value=Query[n][0])
#     sheet.cell(row=row_no+n, column=3, value=Query[n][1])
#     sheet.cell(row=row_no+n, column=4, value=Answer[n][0])
#     sheet.cell(row=row_no+n, column=5, value=Answer[n][1])

# wb.save('/content/sampling.xlsx')
wb.close()
# Out:
# 0 번:  사전 피임약 원리
# 1 번:  몸/건강/임신에 미치는 영향 2 번:  사전 피임약 정의 3 번:  사전 피임약 종류 4 번:  사전 피임약 구입 방법 5 번:  사전 피임약 성분 6 번:  피임 효과
# 7 번:  배란에 미치는 효과 8 번:  생리에 미치는 효과 9 번:  다낭성난소증후군에 미치는 효과 10 번:  기존 질환이 있는 경우 11 번:  섭취 방법 12 번:  섭취 시간 (복용시간)
# 13 번:  복용 시기 (복용 나이) 14 번:  휴약기 15 번:  휴약기간 16 번:  생리 끝나지 않을 경우 17 번:  생리 하지 않을 경우 18 번:  생리 시작 여부
# 19 번:  복용 기간 중 생리 시작할 경우 20 번:  복용 후 임신 가능성(일반) 21 번:  복용 후 임신 가능성(특이사항) 22 번:  지난 달 복용하지 않은 경우 / 첫 복용 경우 23 번:  기존 복용하던 피임제에서 바꾸는 경우 24 번:  주사제, 자궁내피임장치에서 바꾸는 경우
# 25 번:  임신 첫 3개월 내 유산 후 26 번:  출산 후 또는 임신 4~6개월 내 유산 후 27 번:  주기를 변경하거나 연장할 경우(일반) 28 번:  주기를 변경하거나 연장할 경우(특이사항) 29 번:  휴약기 후 잊었을 경우 30 번:  복용을 잊어버린 후 12시간 이내 생각이 났다면
# 31 번:  복용을 잊어버린 후 12시간이 지나서 생각이 났다면-복용 1주차인 경우 32 번:  복용을 잊어버린 후 12시간이 지나서 생각이 났다면-복용 2주차인 경우 33 번:  복용을 잊어버린 후 12시간이 지나서 생각이 났다면-복용 3주차인 경우 34 번:  복용을 잊은 정제가 호르몬제인 연분홍색 정제이고 1정을 잊은 경우 35 번:  복용 1, 2주차에 연분홍색 정제 복용을 2정 이상 잊어버린 경우 36 번:  복용 3, 4주차에 연분홍색 정제 복용을 2 정 이상 잊어버린 경우-생리 첫날 복용 시작
# 37 번:  복용 3, 4주차에 연분홍색 정제 복용을 2 정 이상 잊어버린 경우-일요일 복용 시작 38 번:  흰색(위약) 정제의 경우 39 번:  복용을 잊은 뒤 12시간 이내 생각이 난 경우 40 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용1~17일차 41 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용18~24일차 42 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용25~26일차
# 43 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용27~28일차 44 번:  중단 방법 45 번:  일반적 주의사항 46 번:  복용 전 주의해야할 대상 47 번:  같이먹으면 안되는 음식 48 번:  같이 먹으면 안되는 약
# 49 번:  주의해야할 약 50 번:  부정출혈 51 번:  다리 저림 52 번:  심혈관계 53 번:  비뇨생식기계 54 번:  유방
# 55 번:  소화기계 56 번:  중추신경계 57 번:  피부 58 번:  눈 59 번:  귀 60 번:  대사
# 61 번:  기타 62 번:  보관방법 63 번:  사후 피임약 원리 64 번:  몸/건강/임신에 미치는 영향 65 번:  사후 피임약 정의 66 번:  복용해야 할 경우
# 67 번:  사후 피임약 종류 68 번:  사후 피임약 구입 방법 69 번:  사후 피임약 성분 70 번:  피임 효과가 있는 경우 71 번:  피임 효과가 없는 경우 72 번:  사전 피임제를 복용 중인 경우
# 73 번:  사후 피임제를 최근 복용한 경우 74 번:  생리 하지 않을 경우 75 번:  생리가 끝나지 않을 경우 76 번:  부정출혈 77 번:  두통, 어지러움, 구토
#
# 질문 =  제가 생리주기 맞춘다고 베란 촉진제약을 처방 받아서 9을 10월 두 달 복용했거든요 9월 5일 생리 시작해서 11일에 끝났구요 10월 도 10월 5일에 시작해서 11일에 끝났어요 남친과 10월 22일 날 관계를 가졌는데요 가임기여서 콘돔도 착용했구요 근데 빠진 줄 모르고 하다가 밤 10시 40분쯤 질 내 사정을 했어요 그래서 디음날 낮 1시 40분쯤에 바로 사 후 피임약 노레보 원정을 처방 받아서 먹었거든요... 24시간 이내에 복용해서 임심 가능성 낮겠죠..?ㅠ 걱정됩니다 ㅠ 복용 후 생리는 언제 할까요 ㅠ 예정일이 11월 5일인데 ㅠㅠ 답변 부탁드릴께요
# 답변 =  빠른 노*보 처방 후 복용은 충분히 잘하신 일입니다. 현재 상황으로만 본다면 현실적으로 임신이 될 가능성은 없다고 봐도 무방하지만, 100% 장담은 할 수 없습니다. 생리 시작일을 예측하는 것은 더 어려운 일입니다. 경과 관찰 하시기를 권유합니다.
# 질문 요약문을 입력하세요 : 노레보  복용 후 생리는 언제 할까요
# 답변 요약문을 입력하세요 : 생리 시작일을 예측하는 것은 더 어려운 일입니다.
# 0~77중 분류를 입력하세요 : 73
# last index :  2059
# 0 번:  사전 피임약 원리
# 1 번:  몸/건강/임신에 미치는 영향 2 번:  사전 피임약 정의 3 번:  사전 피임약 종류 4 번:  사전 피임약 구입 방법 5 번:  사전 피임약 성분 6 번:  피임 효과
# 7 번:  배란에 미치는 효과 8 번:  생리에 미치는 효과 9 번:  다낭성난소증후군에 미치는 효과 10 번:  기존 질환이 있는 경우 11 번:  섭취 방법 12 번:  섭취 시간 (복용시간)
# 13 번:  복용 시기 (복용 나이) 14 번:  휴약기 15 번:  휴약기간 16 번:  생리 끝나지 않을 경우 17 번:  생리 하지 않을 경우 18 번:  생리 시작 여부
# 19 번:  복용 기간 중 생리 시작할 경우 20 번:  복용 후 임신 가능성(일반) 21 번:  복용 후 임신 가능성(특이사항) 22 번:  지난 달 복용하지 않은 경우 / 첫 복용 경우 23 번:  기존 복용하던 피임제에서 바꾸는 경우 24 번:  주사제, 자궁내피임장치에서 바꾸는 경우
# 25 번:  임신 첫 3개월 내 유산 후 26 번:  출산 후 또는 임신 4~6개월 내 유산 후 27 번:  주기를 변경하거나 연장할 경우(일반) 28 번:  주기를 변경하거나 연장할 경우(특이사항) 29 번:  휴약기 후 잊었을 경우 30 번:  복용을 잊어버린 후 12시간 이내 생각이 났다면
# 31 번:  복용을 잊어버린 후 12시간이 지나서 생각이 났다면-복용 1주차인 경우 32 번:  복용을 잊어버린 후 12시간이 지나서 생각이 났다면-복용 2주차인 경우 33 번:  복용을 잊어버린 후 12시간이 지나서 생각이 났다면-복용 3주차인 경우 34 번:  복용을 잊은 정제가 호르몬제인 연분홍색 정제이고 1정을 잊은 경우 35 번:  복용 1, 2주차에 연분홍색 정제 복용을 2정 이상 잊어버린 경우 36 번:  복용 3, 4주차에 연분홍색 정제 복용을 2 정 이상 잊어버린 경우-생리 첫날 복용 시작
# 37 번:  복용 3, 4주차에 연분홍색 정제 복용을 2 정 이상 잊어버린 경우-일요일 복용 시작 38 번:  흰색(위약) 정제의 경우 39 번:  복용을 잊은 뒤 12시간 이내 생각이 난 경우 40 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용1~17일차 41 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용18~24일차 42 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용25~26일차
# 43 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용27~28일차 44 번:  중단 방법 45 번:  일반적 주의사항 46 번:  복용 전 주의해야할 대상 47 번:  같이먹으면 안되는 음식 48 번:  같이 먹으면 안되는 약
# 49 번:  주의해야할 약 50 번:  부정출혈 51 번:  다리 저림 52 번:  심혈관계 53 번:  비뇨생식기계 54 번:  유방
# 55 번:  소화기계 56 번:  중추신경계 57 번:  피부 58 번:  눈 59 번:  귀 60 번:  대사
# 61 번:  기타 62 번:  보관방법 63 번:  사후 피임약 원리 64 번:  몸/건강/임신에 미치는 영향 65 번:  사후 피임약 정의 66 번:  복용해야 할 경우
# 67 번:  사후 피임약 종류 68 번:  사후 피임약 구입 방법 69 번:  사후 피임약 성분 70 번:  피임 효과가 있는 경우 71 번:  피임 효과가 없는 경우 72 번:  사전 피임제를 복용 중인 경우
# 73 번:  사후 피임제를 최근 복용한 경우 74 번:  생리 하지 않을 경우 75 번:  생리가 끝나지 않을 경우 76 번:  부정출혈 77 번:  두통, 어지러움, 구토
#
# 질문 =  제가 생리주기 맞춘다고 베란 촉진제약을 처방 받아서 9을 10월 두 달 복용했거든요 9월 5일 생리 시작해서 11일에 끝났구요 10월 도 10월 5일에 시작해서 11일에 끝났어요 남친과 10월 22일 날 관계를 가졌는데요 가임기여서 콘돔도 착용했구요 근데 빠진 줄 모르고 하다가 밤 10시 40분쯤 질 내 사정을 했어요 그래서 디음날 낮 1시 40분쯤에 바로 사 후 피임약 노레보 원정을 처방 받아서 먹었거든요... 24시간 이내에 복용해서 임심 가능성 낮겠죠..?ㅠ 걱정됩니다 ㅠ 복용 후 생리는 언제 할까요 ㅠ 예정일이 11월 5일인데 ㅠㅠ 답변 부탁드릴께요
# 답변 =  확률적으로는 임신이 될 가능성이 높지는 않습니다. 노*보의 빠른 복용은 잘 하셨구요. 단, 여기에서 100% 장담을 할 수 있는 사람은 아무도 없습니다. 우선 경과 관찰하시기를 권유합니다.
# 질문 요약문을 입력하세요 : 중복
# 답변 요약문을 입력하세요 : 중복
# 0~77중 분류를 입력하세요 : 61
# last index :  2060
# 0 번:  사전 피임약 원리
# 1 번:  몸/건강/임신에 미치는 영향 2 번:  사전 피임약 정의 3 번:  사전 피임약 종류 4 번:  사전 피임약 구입 방법 5 번:  사전 피임약 성분 6 번:  피임 효과
# 7 번:  배란에 미치는 효과 8 번:  생리에 미치는 효과 9 번:  다낭성난소증후군에 미치는 효과 10 번:  기존 질환이 있는 경우 11 번:  섭취 방법 12 번:  섭취 시간 (복용시간)
# 13 번:  복용 시기 (복용 나이) 14 번:  휴약기 15 번:  휴약기간 16 번:  생리 끝나지 않을 경우 17 번:  생리 하지 않을 경우 18 번:  생리 시작 여부
# 19 번:  복용 기간 중 생리 시작할 경우 20 번:  복용 후 임신 가능성(일반) 21 번:  복용 후 임신 가능성(특이사항) 22 번:  지난 달 복용하지 않은 경우 / 첫 복용 경우 23 번:  기존 복용하던 피임제에서 바꾸는 경우 24 번:  주사제, 자궁내피임장치에서 바꾸는 경우
# 25 번:  임신 첫 3개월 내 유산 후 26 번:  출산 후 또는 임신 4~6개월 내 유산 후 27 번:  주기를 변경하거나 연장할 경우(일반) 28 번:  주기를 변경하거나 연장할 경우(특이사항) 29 번:  휴약기 후 잊었을 경우 30 번:  복용을 잊어버린 후 12시간 이내 생각이 났다면
# 31 번:  복용을 잊어버린 후 12시간이 지나서 생각이 났다면-복용 1주차인 경우 32 번:  복용을 잊어버린 후 12시간이 지나서 생각이 났다면-복용 2주차인 경우 33 번:  복용을 잊어버린 후 12시간이 지나서 생각이 났다면-복용 3주차인 경우 34 번:  복용을 잊은 정제가 호르몬제인 연분홍색 정제이고 1정을 잊은 경우 35 번:  복용 1, 2주차에 연분홍색 정제 복용을 2정 이상 잊어버린 경우 36 번:  복용 3, 4주차에 연분홍색 정제 복용을 2 정 이상 잊어버린 경우-생리 첫날 복용 시작
# 37 번:  복용 3, 4주차에 연분홍색 정제 복용을 2 정 이상 잊어버린 경우-일요일 복용 시작 38 번:  흰색(위약) 정제의 경우 39 번:  복용을 잊은 뒤 12시간 이내 생각이 난 경우 40 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용1~17일차 41 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용18~24일차 42 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용25~26일차
# 43 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용27~28일차 44 번:  중단 방법 45 번:  일반적 주의사항 46 번:  복용 전 주의해야할 대상 47 번:  같이먹으면 안되는 음식 48 번:  같이 먹으면 안되는 약
# 49 번:  주의해야할 약 50 번:  부정출혈 51 번:  다리 저림 52 번:  심혈관계 53 번:  비뇨생식기계 54 번:  유방
# 55 번:  소화기계 56 번:  중추신경계 57 번:  피부 58 번:  눈 59 번:  귀 60 번:  대사
# 61 번:  기타 62 번:  보관방법 63 번:  사후 피임약 원리 64 번:  몸/건강/임신에 미치는 영향 65 번:  사후 피임약 정의 66 번:  복용해야 할 경우
# 67 번:  사후 피임약 종류 68 번:  사후 피임약 구입 방법 69 번:  사후 피임약 성분 70 번:  피임 효과가 있는 경우 71 번:  피임 효과가 없는 경우 72 번:  사전 피임제를 복용 중인 경우
# 73 번:  사후 피임제를 최근 복용한 경우 74 번:  생리 하지 않을 경우 75 번:  생리가 끝나지 않을 경우 76 번:  부정출혈 77 번:  두통, 어지러움, 구토
#
# 질문 =  21일 저녁에 생리를 시작해서 22일부터 피임약을 복용하기 시작했습니다. 날짜에 따르면 7월 12일까지 복용하고 19일까지 휴약기입니다. 그러고 20일부터 다시 복용을 시작합니다. 다낭성 난소증후군 소견을 받아서 가능하면 임플라논을 시술하고 싶습니다. 그런데 제가 7월 28일밖에 시간을 못 내요. 임플라논을 저 날 시술 받고 싶은데 피임약 복용을 어떻게 해야 할까요?
# 답변 =  제일 좋은 방법은 피임약 휴약기에 삽입하는 게 이상적이지만 시간이 여의치 않을 경우에는 7월 20일 부터 피임약 복용을 시작하고 7월 28일 임플라논 삽입 후에는 피임약 복용을 중단하고 임플라논 삽입 후 7일 간은 차단 피임법 (콘돔) 을 사용하기 바랍니다. 자세한 상담은 임플라논 삽입 위해 병원 내원 시 주치의 선생님과 하기 바랍니다.
# 질문 요약문을 입력하세요 : 다낭성 난소증후군 소견을 받아서 가능하면 임플라논을 시술하고 싶습니다. 피임약 복용을 어떻게 해야 할까요?
# 답변 요약문을 입력하세요 : 임플라논 삽입 후에는 피임약 복용을 중단하고 임플라논 삽입 후 7일 간은 차단 피임법 (콘돔) 을 사용하기 바랍니다.
# 0~77중 분류를 입력하세요 : 37
# last index :  2061
# 0 번:  사전 피임약 원리
# 1 번:  몸/건강/임신에 미치는 영향 2 번:  사전 피임약 정의 3 번:  사전 피임약 종류 4 번:  사전 피임약 구입 방법 5 번:  사전 피임약 성분 6 번:  피임 효과
# 7 번:  배란에 미치는 효과 8 번:  생리에 미치는 효과 9 번:  다낭성난소증후군에 미치는 효과 10 번:  기존 질환이 있는 경우 11 번:  섭취 방법 12 번:  섭취 시간 (복용시간)
# 13 번:  복용 시기 (복용 나이) 14 번:  휴약기 15 번:  휴약기간 16 번:  생리 끝나지 않을 경우 17 번:  생리 하지 않을 경우 18 번:  생리 시작 여부
# 19 번:  복용 기간 중 생리 시작할 경우 20 번:  복용 후 임신 가능성(일반) 21 번:  복용 후 임신 가능성(특이사항) 22 번:  지난 달 복용하지 않은 경우 / 첫 복용 경우 23 번:  기존 복용하던 피임제에서 바꾸는 경우 24 번:  주사제, 자궁내피임장치에서 바꾸는 경우
# 25 번:  임신 첫 3개월 내 유산 후 26 번:  출산 후 또는 임신 4~6개월 내 유산 후 27 번:  주기를 변경하거나 연장할 경우(일반) 28 번:  주기를 변경하거나 연장할 경우(특이사항) 29 번:  휴약기 후 잊었을 경우 30 번:  복용을 잊어버린 후 12시간 이내 생각이 났다면
# 31 번:  복용을 잊어버린 후 12시간이 지나서 생각이 났다면-복용 1주차인 경우 32 번:  복용을 잊어버린 후 12시간이 지나서 생각이 났다면-복용 2주차인 경우 33 번:  복용을 잊어버린 후 12시간이 지나서 생각이 났다면-복용 3주차인 경우 34 번:  복용을 잊은 정제가 호르몬제인 연분홍색 정제이고 1정을 잊은 경우 35 번:  복용 1, 2주차에 연분홍색 정제 복용을 2정 이상 잊어버린 경우 36 번:  복용 3, 4주차에 연분홍색 정제 복용을 2 정 이상 잊어버린 경우-생리 첫날 복용 시작
# 37 번:  복용 3, 4주차에 연분홍색 정제 복용을 2 정 이상 잊어버린 경우-일요일 복용 시작 38 번:  흰색(위약) 정제의 경우 39 번:  복용을 잊은 뒤 12시간 이내 생각이 난 경우 40 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용1~17일차 41 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용18~24일차 42 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용25~26일차
# 43 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용27~28일차 44 번:  중단 방법 45 번:  일반적 주의사항 46 번:  복용 전 주의해야할 대상 47 번:  같이먹으면 안되는 음식 48 번:  같이 먹으면 안되는 약
# 49 번:  주의해야할 약 50 번:  부정출혈 51 번:  다리 저림 52 번:  심혈관계 53 번:  비뇨생식기계 54 번:  유방
# 55 번:  소화기계 56 번:  중추신경계 57 번:  피부 58 번:  눈 59 번:  귀 60 번:  대사
# 61 번:  기타 62 번:  보관방법 63 번:  사후 피임약 원리 64 번:  몸/건강/임신에 미치는 영향 65 번:  사후 피임약 정의 66 번:  복용해야 할 경우
# 67 번:  사후 피임약 종류 68 번:  사후 피임약 구입 방법 69 번:  사후 피임약 성분 70 번:  피임 효과가 있는 경우 71 번:  피임 효과가 없는 경우 72 번:  사전 피임제를 복용 중인 경우
# 73 번:  사후 피임제를 최근 복용한 경우 74 번:  생리 하지 않을 경우 75 번:  생리가 끝나지 않을 경우 76 번:  부정출혈 77 번:  두통, 어지러움, 구토
#
# 질문 =  사후 피임약을 복용 후 다음날 또 관계를 했는데 안에 조금 들어간 것 같은데 임신 가능성이 있나요? 만약 임신이 되면 사 후 피임약 복용 후 관계가 임신이 되는 거죠? 사후 피임약 먹기 전 관계의 임신은 막아지는 거죠? 불안하네요 ㅠ
# 답변 =  불안해도 사 후 피임약이 100% 피임을 할 수 있는 방법은 아니 기 때문에 관계 후 2주 지난 시점에 임신테스트 시행하기 바랍니다.
# 질문 요약문을 입력하세요 : 사후 피임약을 복용 후 다음 날 관계를 맺으면 임신 가능성이 있나요?
# 답변 요약문을 입력하세요 : 사 후 피임약이 100% 피임을 할 수 있는 방법은 아니 기 때문에
# 0~77중 분류를 입력하세요 : 73
# last index :  2062
# 0 번:  사전 피임약 원리
# 1 번:  몸/건강/임신에 미치는 영향 2 번:  사전 피임약 정의 3 번:  사전 피임약 종류 4 번:  사전 피임약 구입 방법 5 번:  사전 피임약 성분 6 번:  피임 효과
# 7 번:  배란에 미치는 효과 8 번:  생리에 미치는 효과 9 번:  다낭성난소증후군에 미치는 효과 10 번:  기존 질환이 있는 경우 11 번:  섭취 방법 12 번:  섭취 시간 (복용시간)
# 13 번:  복용 시기 (복용 나이) 14 번:  휴약기 15 번:  휴약기간 16 번:  생리 끝나지 않을 경우 17 번:  생리 하지 않을 경우 18 번:  생리 시작 여부
# 19 번:  복용 기간 중 생리 시작할 경우 20 번:  복용 후 임신 가능성(일반) 21 번:  복용 후 임신 가능성(특이사항) 22 번:  지난 달 복용하지 않은 경우 / 첫 복용 경우 23 번:  기존 복용하던 피임제에서 바꾸는 경우 24 번:  주사제, 자궁내피임장치에서 바꾸는 경우
# 25 번:  임신 첫 3개월 내 유산 후 26 번:  출산 후 또는 임신 4~6개월 내 유산 후 27 번:  주기를 변경하거나 연장할 경우(일반) 28 번:  주기를 변경하거나 연장할 경우(특이사항) 29 번:  휴약기 후 잊었을 경우 30 번:  복용을 잊어버린 후 12시간 이내 생각이 났다면
# 31 번:  복용을 잊어버린 후 12시간이 지나서 생각이 났다면-복용 1주차인 경우 32 번:  복용을 잊어버린 후 12시간이 지나서 생각이 났다면-복용 2주차인 경우 33 번:  복용을 잊어버린 후 12시간이 지나서 생각이 났다면-복용 3주차인 경우 34 번:  복용을 잊은 정제가 호르몬제인 연분홍색 정제이고 1정을 잊은 경우 35 번:  복용 1, 2주차에 연분홍색 정제 복용을 2정 이상 잊어버린 경우 36 번:  복용 3, 4주차에 연분홍색 정제 복용을 2 정 이상 잊어버린 경우-생리 첫날 복용 시작
# 37 번:  복용 3, 4주차에 연분홍색 정제 복용을 2 정 이상 잊어버린 경우-일요일 복용 시작 38 번:  흰색(위약) 정제의 경우 39 번:  복용을 잊은 뒤 12시간 이내 생각이 난 경우 40 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용1~17일차 41 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용18~24일차 42 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용25~26일차
# 43 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용27~28일차 44 번:  중단 방법 45 번:  일반적 주의사항 46 번:  복용 전 주의해야할 대상 47 번:  같이먹으면 안되는 음식 48 번:  같이 먹으면 안되는 약
# 49 번:  주의해야할 약 50 번:  부정출혈 51 번:  다리 저림 52 번:  심혈관계 53 번:  비뇨생식기계 54 번:  유방
# 55 번:  소화기계 56 번:  중추신경계 57 번:  피부 58 번:  눈 59 번:  귀 60 번:  대사
# 61 번:  기타 62 번:  보관방법 63 번:  사후 피임약 원리 64 번:  몸/건강/임신에 미치는 영향 65 번:  사후 피임약 정의 66 번:  복용해야 할 경우
# 67 번:  사후 피임약 종류 68 번:  사후 피임약 구입 방법 69 번:  사후 피임약 성분 70 번:  피임 효과가 있는 경우 71 번:  피임 효과가 없는 경우 72 번:  사전 피임제를 복용 중인 경우
# 73 번:  사후 피임제를 최근 복용한 경우 74 번:  생리 하지 않을 경우 75 번:  생리가 끝나지 않을 경우 76 번:  부정출혈 77 번:  두통, 어지러움, 구토
#
# 질문 =  경구 피임약을 복용하기 시작했는데요. 매일 밤 12시쯤에 제가 복용하기 편할 것 같아 정했는데... 첫날은 자정에 딱 맞춰서 먹었는데, 어젠 깜빡하고 못 먹었어요 ㅠㅠ 아침에 화들짝 놀래서 먹었는데... 24시간 안에 약을 먹어야 된다고 하던데... 9시간 이 지나서 피임약을 먹어도 괜찮을까요? 오늘부터는 밤 12시에 꼬박꼬박 먹으려구요 ㅠ 그리고, 피임약의 효과는 복용 후 일주일 후에 나타나나요? 현재 생리 중이긴 해요.ㅎ
# 답변 =  어제 복용하지 못한 피임약은 다음날 생각이 났을 때 바로 복용하면 됩니다. 다음날, 즉 오늘 2알을 한 꺼번에 복용해도 상관이 없습니다. 그러나 2일 이상 복용을 잊은 경우에는 부정출혈이 있을 수 있으므로 주의하셔야 합니다. 피임약은 생리 시작 5일 이내에 복용하기 시작하면 다음 배란은 억제되기 때문에 피임 효과가 있습니다. 답변이 도움 되셨기를 바랍니다.
# 질문 요약문을 입력하세요 : 경구 피임약 복용 후 이 틀날 못먹었어요. 피임약의 효과는 복용 후 일주일 후에 나타나나요?
# 답변 요약문을 입력하세요 :  즉 오늘 2알을 한 꺼번에 복용해도 상관이 없습니다. 하지만 부정출혈이 발생할 수 있습니다
# 0~77중 분류를 입력하세요 : 30
# last index :  2063
# 0 번:  사전 피임약 원리
# 1 번:  몸/건강/임신에 미치는 영향 2 번:  사전 피임약 정의 3 번:  사전 피임약 종류 4 번:  사전 피임약 구입 방법 5 번:  사전 피임약 성분 6 번:  피임 효과
# 7 번:  배란에 미치는 효과 8 번:  생리에 미치는 효과 9 번:  다낭성난소증후군에 미치는 효과 10 번:  기존 질환이 있는 경우 11 번:  섭취 방법 12 번:  섭취 시간 (복용시간)
# 13 번:  복용 시기 (복용 나이) 14 번:  휴약기 15 번:  휴약기간 16 번:  생리 끝나지 않을 경우 17 번:  생리 하지 않을 경우 18 번:  생리 시작 여부
# 19 번:  복용 기간 중 생리 시작할 경우 20 번:  복용 후 임신 가능성(일반) 21 번:  복용 후 임신 가능성(특이사항) 22 번:  지난 달 복용하지 않은 경우 / 첫 복용 경우 23 번:  기존 복용하던 피임제에서 바꾸는 경우 24 번:  주사제, 자궁내피임장치에서 바꾸는 경우
# 25 번:  임신 첫 3개월 내 유산 후 26 번:  출산 후 또는 임신 4~6개월 내 유산 후 27 번:  주기를 변경하거나 연장할 경우(일반) 28 번:  주기를 변경하거나 연장할 경우(특이사항) 29 번:  휴약기 후 잊었을 경우 30 번:  복용을 잊어버린 후 12시간 이내 생각이 났다면
# 31 번:  복용을 잊어버린 후 12시간이 지나서 생각이 났다면-복용 1주차인 경우 32 번:  복용을 잊어버린 후 12시간이 지나서 생각이 났다면-복용 2주차인 경우 33 번:  복용을 잊어버린 후 12시간이 지나서 생각이 났다면-복용 3주차인 경우 34 번:  복용을 잊은 정제가 호르몬제인 연분홍색 정제이고 1정을 잊은 경우 35 번:  복용 1, 2주차에 연분홍색 정제 복용을 2정 이상 잊어버린 경우 36 번:  복용 3, 4주차에 연분홍색 정제 복용을 2 정 이상 잊어버린 경우-생리 첫날 복용 시작
# 37 번:  복용 3, 4주차에 연분홍색 정제 복용을 2 정 이상 잊어버린 경우-일요일 복용 시작 38 번:  흰색(위약) 정제의 경우 39 번:  복용을 잊은 뒤 12시간 이내 생각이 난 경우 40 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용1~17일차 41 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용18~24일차 42 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용25~26일차
# 43 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용27~28일차 44 번:  중단 방법 45 번:  일반적 주의사항 46 번:  복용 전 주의해야할 대상 47 번:  같이먹으면 안되는 음식 48 번:  같이 먹으면 안되는 약
# 49 번:  주의해야할 약 50 번:  부정출혈 51 번:  다리 저림 52 번:  심혈관계 53 번:  비뇨생식기계 54 번:  유방
# 55 번:  소화기계 56 번:  중추신경계 57 번:  피부 58 번:  눈 59 번:  귀 60 번:  대사
# 61 번:  기타 62 번:  보관방법 63 번:  사후 피임약 원리 64 번:  몸/건강/임신에 미치는 영향 65 번:  사후 피임약 정의 66 번:  복용해야 할 경우
# 67 번:  사후 피임약 종류 68 번:  사후 피임약 구입 방법 69 번:  사후 피임약 성분 70 번:  피임 효과가 있는 경우 71 번:  피임 효과가 없는 경우 72 번:  사전 피임제를 복용 중인 경우
# 73 번:  사후 피임제를 최근 복용한 경우 74 번:  생리 하지 않을 경우 75 번:  생리가 끝나지 않을 경우 76 번:  부정출혈 77 번:  두통, 어지러움, 구토
#
# 질문 =  여자친구가 약 10일 정도 피임약을 복용했구요.. 관계를 가지고 1주일 뒤 생리를 평소 생리주기보다 더 이르게 했습니다. 생리인지 소퇴성출혈인지 구분이 안 가서요. 만약 소퇴성 출혈이라도 생리와 동일하게 임신 가능성은 없는 건가요? 생리양은 평소 생리 양보다 조금 더 많았다고 합니다.
# 답변 =  임신 가능성은 낮아 보입니다. 너무 걱정하지 않으셔도 될 듯 합니다. 답변을 참고하시기 전에 1. 온라인 상에서의 답변은 제한적인 정보에 따른 견해로 법적인 책임이 없는 참고 정보로만 고려해 주세요. 2. 정확한 의학적 검진과 판단은 가까운 병원에 방문하셔서 전문의에게 들으시기 바랍니다.
# 질문 요약문을 입력하세요 : 10일 정도 피임약을 복용했구요 평소 생리주기보다 더 이르게 했습니다생리인지 소퇴성출혈인지 구분이 안 가서요.
# 답변 요약문을 입력하세요 : 임신 가능성은 낮아 보입니다.
# 0~77중 분류를 입력하세요 : 61
# last index :  2064
# 0 번:  사전 피임약 원리
# 1 번:  몸/건강/임신에 미치는 영향 2 번:  사전 피임약 정의 3 번:  사전 피임약 종류 4 번:  사전 피임약 구입 방법 5 번:  사전 피임약 성분 6 번:  피임 효과
# 7 번:  배란에 미치는 효과 8 번:  생리에 미치는 효과 9 번:  다낭성난소증후군에 미치는 효과 10 번:  기존 질환이 있는 경우 11 번:  섭취 방법 12 번:  섭취 시간 (복용시간)
# 13 번:  복용 시기 (복용 나이) 14 번:  휴약기 15 번:  휴약기간 16 번:  생리 끝나지 않을 경우 17 번:  생리 하지 않을 경우 18 번:  생리 시작 여부
# 19 번:  복용 기간 중 생리 시작할 경우 20 번:  복용 후 임신 가능성(일반) 21 번:  복용 후 임신 가능성(특이사항) 22 번:  지난 달 복용하지 않은 경우 / 첫 복용 경우 23 번:  기존 복용하던 피임제에서 바꾸는 경우 24 번:  주사제, 자궁내피임장치에서 바꾸는 경우
# 25 번:  임신 첫 3개월 내 유산 후 26 번:  출산 후 또는 임신 4~6개월 내 유산 후 27 번:  주기를 변경하거나 연장할 경우(일반) 28 번:  주기를 변경하거나 연장할 경우(특이사항) 29 번:  휴약기 후 잊었을 경우 30 번:  복용을 잊어버린 후 12시간 이내 생각이 났다면
# 31 번:  복용을 잊어버린 후 12시간이 지나서 생각이 났다면-복용 1주차인 경우 32 번:  복용을 잊어버린 후 12시간이 지나서 생각이 났다면-복용 2주차인 경우 33 번:  복용을 잊어버린 후 12시간이 지나서 생각이 났다면-복용 3주차인 경우 34 번:  복용을 잊은 정제가 호르몬제인 연분홍색 정제이고 1정을 잊은 경우 35 번:  복용 1, 2주차에 연분홍색 정제 복용을 2정 이상 잊어버린 경우 36 번:  복용 3, 4주차에 연분홍색 정제 복용을 2 정 이상 잊어버린 경우-생리 첫날 복용 시작
# 37 번:  복용 3, 4주차에 연분홍색 정제 복용을 2 정 이상 잊어버린 경우-일요일 복용 시작 38 번:  흰색(위약) 정제의 경우 39 번:  복용을 잊은 뒤 12시간 이내 생각이 난 경우 40 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용1~17일차 41 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용18~24일차 42 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용25~26일차
# 43 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용27~28일차 44 번:  중단 방법 45 번:  일반적 주의사항 46 번:  복용 전 주의해야할 대상 47 번:  같이먹으면 안되는 음식 48 번:  같이 먹으면 안되는 약
# 49 번:  주의해야할 약 50 번:  부정출혈 51 번:  다리 저림 52 번:  심혈관계 53 번:  비뇨생식기계 54 번:  유방
# 55 번:  소화기계 56 번:  중추신경계 57 번:  피부 58 번:  눈 59 번:  귀 60 번:  대사
# 61 번:  기타 62 번:  보관방법 63 번:  사후 피임약 원리 64 번:  몸/건강/임신에 미치는 영향 65 번:  사후 피임약 정의 66 번:  복용해야 할 경우
# 67 번:  사후 피임약 종류 68 번:  사후 피임약 구입 방법 69 번:  사후 피임약 성분 70 번:  피임 효과가 있는 경우 71 번:  피임 효과가 없는 경우 72 번:  사전 피임제를 복용 중인 경우
# 73 번:  사후 피임제를 최근 복용한 경우 74 번:  생리 하지 않을 경우 75 번:  생리가 끝나지 않을 경우 76 번:  부정출혈 77 번:  두통, 어지러움, 구토
#
# 질문 =  2월 22일 피임 없이 관계를 가지고 바로 다음 아침 날 응급피임약을 복용한 후 3월 5일 날 피검사로 임신 가능성 수치 0, 7일 아침 임테기 해보려는데 생리를 했습니다. 그리고 원래 같으면 4월 9일에 생리를 시작했어야 했는데 오늘까지 하고 있지 않습니다. 응급피임약의 부작용이라고 여겨도 되는 걸까요? 괜히 불안해집니다...
# 답변 =  현재 상황으로 보아 임신의 가능성은 떨어질 듯 합니다. 임신으로 인한 무생리보다는 단순 생리지연이나 건너띈 경우 일 듯합니다.
# 질문 요약문을 입력하세요 : 관계를 가지고 다음날 사후 피임약을 복용 했습니다.  후에 생리가 나오지 않습니다. 임신 가능성이 있나요
# 답변 요약문을 입력하세요 : 임신의 가능성은 떨어질 듯 합니다.
# 0~77중 분류를 입력하세요 : 74
# last index :  2065
# 0 번:  사전 피임약 원리
# 1 번:  몸/건강/임신에 미치는 영향 2 번:  사전 피임약 정의 3 번:  사전 피임약 종류 4 번:  사전 피임약 구입 방법 5 번:  사전 피임약 성분 6 번:  피임 효과
# 7 번:  배란에 미치는 효과 8 번:  생리에 미치는 효과 9 번:  다낭성난소증후군에 미치는 효과 10 번:  기존 질환이 있는 경우 11 번:  섭취 방법 12 번:  섭취 시간 (복용시간)
# 13 번:  복용 시기 (복용 나이) 14 번:  휴약기 15 번:  휴약기간 16 번:  생리 끝나지 않을 경우 17 번:  생리 하지 않을 경우 18 번:  생리 시작 여부
# 19 번:  복용 기간 중 생리 시작할 경우 20 번:  복용 후 임신 가능성(일반) 21 번:  복용 후 임신 가능성(특이사항) 22 번:  지난 달 복용하지 않은 경우 / 첫 복용 경우 23 번:  기존 복용하던 피임제에서 바꾸는 경우 24 번:  주사제, 자궁내피임장치에서 바꾸는 경우
# 25 번:  임신 첫 3개월 내 유산 후 26 번:  출산 후 또는 임신 4~6개월 내 유산 후 27 번:  주기를 변경하거나 연장할 경우(일반) 28 번:  주기를 변경하거나 연장할 경우(특이사항) 29 번:  휴약기 후 잊었을 경우 30 번:  복용을 잊어버린 후 12시간 이내 생각이 났다면
# 31 번:  복용을 잊어버린 후 12시간이 지나서 생각이 났다면-복용 1주차인 경우 32 번:  복용을 잊어버린 후 12시간이 지나서 생각이 났다면-복용 2주차인 경우 33 번:  복용을 잊어버린 후 12시간이 지나서 생각이 났다면-복용 3주차인 경우 34 번:  복용을 잊은 정제가 호르몬제인 연분홍색 정제이고 1정을 잊은 경우 35 번:  복용 1, 2주차에 연분홍색 정제 복용을 2정 이상 잊어버린 경우 36 번:  복용 3, 4주차에 연분홍색 정제 복용을 2 정 이상 잊어버린 경우-생리 첫날 복용 시작
# 37 번:  복용 3, 4주차에 연분홍색 정제 복용을 2 정 이상 잊어버린 경우-일요일 복용 시작 38 번:  흰색(위약) 정제의 경우 39 번:  복용을 잊은 뒤 12시간 이내 생각이 난 경우 40 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용1~17일차 41 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용18~24일차 42 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용25~26일차
# 43 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용27~28일차 44 번:  중단 방법 45 번:  일반적 주의사항 46 번:  복용 전 주의해야할 대상 47 번:  같이먹으면 안되는 음식 48 번:  같이 먹으면 안되는 약
# 49 번:  주의해야할 약 50 번:  부정출혈 51 번:  다리 저림 52 번:  심혈관계 53 번:  비뇨생식기계 54 번:  유방
# 55 번:  소화기계 56 번:  중추신경계 57 번:  피부 58 번:  눈 59 번:  귀 60 번:  대사
# 61 번:  기타 62 번:  보관방법 63 번:  사후 피임약 원리 64 번:  몸/건강/임신에 미치는 영향 65 번:  사후 피임약 정의 66 번:  복용해야 할 경우
# 67 번:  사후 피임약 종류 68 번:  사후 피임약 구입 방법 69 번:  사후 피임약 성분 70 번:  피임 효과가 있는 경우 71 번:  피임 효과가 없는 경우 72 번:  사전 피임제를 복용 중인 경우
# 73 번:  사후 피임제를 최근 복용한 경우 74 번:  생리 하지 않을 경우 75 번:  생리가 끝나지 않을 경우 76 번:  부정출혈 77 번:  두통, 어지러움, 구토
#
# 질문 =  치료 목적으로 피임약 야즈를 복용 중입니다 6월 9일에 복용을 시작하여 7월 2일에 24 알 피임약을 다 먹고 남은 4 알 (가짜 약) 위약까지 복용을 어 제 마쳤습니다. 원래 경구피임약 복용은 생리 첫 날부터 복용하는 거라고 하던데 저는 치료 목적인데 다 먹었으니 새 걸 뜯어서 바로 복용해야 하는 지 원래 복용 방법대로 복용해야 하는 지 궁금합니다! 빠른 답변 부탁드릴게요 ㅠㅠ
# 답변 =  치료 목적이었으니 바로 복용하세요.
# 질문 요약문을 입력하세요 : 치료 목적으로 피임약 야즈를 복용 중입니다. 다음 주기에 바로 첫날에 먹어야 하나요
# 답변 요약문을 입력하세요 : 치료 목적이었으니 바로 복용하세요.
# 0~77중 분류를 입력하세요 : 11
# last index :  2066
# 0 번:  사전 피임약 원리
# 1 번:  몸/건강/임신에 미치는 영향 2 번:  사전 피임약 정의 3 번:  사전 피임약 종류 4 번:  사전 피임약 구입 방법 5 번:  사전 피임약 성분 6 번:  피임 효과
# 7 번:  배란에 미치는 효과 8 번:  생리에 미치는 효과 9 번:  다낭성난소증후군에 미치는 효과 10 번:  기존 질환이 있는 경우 11 번:  섭취 방법 12 번:  섭취 시간 (복용시간)
# 13 번:  복용 시기 (복용 나이) 14 번:  휴약기 15 번:  휴약기간 16 번:  생리 끝나지 않을 경우 17 번:  생리 하지 않을 경우 18 번:  생리 시작 여부
# 19 번:  복용 기간 중 생리 시작할 경우 20 번:  복용 후 임신 가능성(일반) 21 번:  복용 후 임신 가능성(특이사항) 22 번:  지난 달 복용하지 않은 경우 / 첫 복용 경우 23 번:  기존 복용하던 피임제에서 바꾸는 경우 24 번:  주사제, 자궁내피임장치에서 바꾸는 경우
# 25 번:  임신 첫 3개월 내 유산 후 26 번:  출산 후 또는 임신 4~6개월 내 유산 후 27 번:  주기를 변경하거나 연장할 경우(일반) 28 번:  주기를 변경하거나 연장할 경우(특이사항) 29 번:  휴약기 후 잊었을 경우 30 번:  복용을 잊어버린 후 12시간 이내 생각이 났다면
# 31 번:  복용을 잊어버린 후 12시간이 지나서 생각이 났다면-복용 1주차인 경우 32 번:  복용을 잊어버린 후 12시간이 지나서 생각이 났다면-복용 2주차인 경우 33 번:  복용을 잊어버린 후 12시간이 지나서 생각이 났다면-복용 3주차인 경우 34 번:  복용을 잊은 정제가 호르몬제인 연분홍색 정제이고 1정을 잊은 경우 35 번:  복용 1, 2주차에 연분홍색 정제 복용을 2정 이상 잊어버린 경우 36 번:  복용 3, 4주차에 연분홍색 정제 복용을 2 정 이상 잊어버린 경우-생리 첫날 복용 시작
# 37 번:  복용 3, 4주차에 연분홍색 정제 복용을 2 정 이상 잊어버린 경우-일요일 복용 시작 38 번:  흰색(위약) 정제의 경우 39 번:  복용을 잊은 뒤 12시간 이내 생각이 난 경우 40 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용1~17일차 41 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용18~24일차 42 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용25~26일차
# 43 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용27~28일차 44 번:  중단 방법 45 번:  일반적 주의사항 46 번:  복용 전 주의해야할 대상 47 번:  같이먹으면 안되는 음식 48 번:  같이 먹으면 안되는 약
# 49 번:  주의해야할 약 50 번:  부정출혈 51 번:  다리 저림 52 번:  심혈관계 53 번:  비뇨생식기계 54 번:  유방
# 55 번:  소화기계 56 번:  중추신경계 57 번:  피부 58 번:  눈 59 번:  귀 60 번:  대사
# 61 번:  기타 62 번:  보관방법 63 번:  사후 피임약 원리 64 번:  몸/건강/임신에 미치는 영향 65 번:  사후 피임약 정의 66 번:  복용해야 할 경우
# 67 번:  사후 피임약 종류 68 번:  사후 피임약 구입 방법 69 번:  사후 피임약 성분 70 번:  피임 효과가 있는 경우 71 번:  피임 효과가 없는 경우 72 번:  사전 피임제를 복용 중인 경우
# 73 번:  사후 피임제를 최근 복용한 경우 74 번:  생리 하지 않을 경우 75 번:  생리가 끝나지 않을 경우 76 번:  부정출혈 77 번:  두통, 어지러움, 구토
#
# 질문 =  25세 여160cm47kg 스무 살쯤부터 생리불순이었는데 따로 몸 관리를 하지 않아 올해 6월부터 수영과 식습관에 신경 쓰고 있습니다. 그쯤 굉장히 몸이 힘들었는데 6월에만 생리를 3번 하고 마지막에 부정출혈이 있어 병원에서 초음파 검사 받지 않고 다낭성증후군에 대한 의사 소견으로 멜리안 정 피임약을 2개월째 복용 중입니다. (3년 전 난소기형 종 수술을 받고 다낭성증후군인 것 같다는 얘길 들었고 올해 4월 말을 마지막으로 초음파 검사 받았습니다.) 1. 다낭성증후군은 피임약으로 고칠 수잇는 건가요? 몇 년 정도 복용해야 하죠? 2. 생리주기가 26일 이하로 떨어지면 난소 기능이 저하된 거라던데 제가 극단적으로 생리 일 포함 10일~60일까지 오가거든요. (..60 34 16 27 49 29 39 17 10 41일..) 피임약을 먹고 있으면 난소 기능이 떨어지지는 않는지, 병원에 가서 검사를 받으려면 어떤 검사를 받아야 하는지 알려주세요ㅠ
# 답변 =  네, 생리불순으로 걱정이 되셨군요. 다낭성 난소증후군은 호르몬 불균형으로 배란이 잘 안 되어 생리불순이 오는 것으로 피임약은 다낭성난소증후군을 치료하는 것은 아니랍니다. 피임약을 복용하여 신체 내 생리주기를 없앤 후 차 후에 피임약을 떼고 몸이 주기를 다시 찾는지를 확인하는 것입니다. 피임약으로 난소의 기능이 떨어지지는 않습니다. 병원에 내 원하셔서 난 소나이를 측정하는 피검사를 받아서 난소의 기능을 확인해 보시길 바랍니다. 문의에 도움이 되셨기를 바랍니다.
# 질문 요약문을 입력하세요 : 다낭성증후군은 피임약으로 고칠 수잇는 건가요?
# 답변 요약문을 입력하세요 : 피임약은 다낭성난소증후군을 치료하는 것은 아니랍니다.
# 0~77중 분류를 입력하세요 : 61
# last index :  2067
# 0 번:  사전 피임약 원리
# 1 번:  몸/건강/임신에 미치는 영향 2 번:  사전 피임약 정의 3 번:  사전 피임약 종류 4 번:  사전 피임약 구입 방법 5 번:  사전 피임약 성분 6 번:  피임 효과
# 7 번:  배란에 미치는 효과 8 번:  생리에 미치는 효과 9 번:  다낭성난소증후군에 미치는 효과 10 번:  기존 질환이 있는 경우 11 번:  섭취 방법 12 번:  섭취 시간 (복용시간)
# 13 번:  복용 시기 (복용 나이) 14 번:  휴약기 15 번:  휴약기간 16 번:  생리 끝나지 않을 경우 17 번:  생리 하지 않을 경우 18 번:  생리 시작 여부
# 19 번:  복용 기간 중 생리 시작할 경우 20 번:  복용 후 임신 가능성(일반) 21 번:  복용 후 임신 가능성(특이사항) 22 번:  지난 달 복용하지 않은 경우 / 첫 복용 경우 23 번:  기존 복용하던 피임제에서 바꾸는 경우 24 번:  주사제, 자궁내피임장치에서 바꾸는 경우
# 25 번:  임신 첫 3개월 내 유산 후 26 번:  출산 후 또는 임신 4~6개월 내 유산 후 27 번:  주기를 변경하거나 연장할 경우(일반) 28 번:  주기를 변경하거나 연장할 경우(특이사항) 29 번:  휴약기 후 잊었을 경우 30 번:  복용을 잊어버린 후 12시간 이내 생각이 났다면
# 31 번:  복용을 잊어버린 후 12시간이 지나서 생각이 났다면-복용 1주차인 경우 32 번:  복용을 잊어버린 후 12시간이 지나서 생각이 났다면-복용 2주차인 경우 33 번:  복용을 잊어버린 후 12시간이 지나서 생각이 났다면-복용 3주차인 경우 34 번:  복용을 잊은 정제가 호르몬제인 연분홍색 정제이고 1정을 잊은 경우 35 번:  복용 1, 2주차에 연분홍색 정제 복용을 2정 이상 잊어버린 경우 36 번:  복용 3, 4주차에 연분홍색 정제 복용을 2 정 이상 잊어버린 경우-생리 첫날 복용 시작
# 37 번:  복용 3, 4주차에 연분홍색 정제 복용을 2 정 이상 잊어버린 경우-일요일 복용 시작 38 번:  흰색(위약) 정제의 경우 39 번:  복용을 잊은 뒤 12시간 이내 생각이 난 경우 40 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용1~17일차 41 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용18~24일차 42 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용25~26일차
# 43 번:  복용을 잊은 뒤 12시간이 경과하였다면-복용27~28일차 44 번:  중단 방법 45 번:  일반적 주의사항 46 번:  복용 전 주의해야할 대상 47 번:  같이먹으면 안되는 음식 48 번:  같이 먹으면 안되는 약
# 49 번:  주의해야할 약 50 번:  부정출혈 51 번:  다리 저림 52 번:  심혈관계 53 번:  비뇨생식기계 54 번:  유방
# 55 번:  소화기계 56 번:  중추신경계 57 번:  피부 58 번:  눈 59 번:  귀 60 번:  대사
# 61 번:  기타 62 번:  보관방법 63 번:  사후 피임약 원리 64 번:  몸/건강/임신에 미치는 영향 65 번:  사후 피임약 정의 66 번:  복용해야 할 경우
# 67 번:  사후 피임약 종류 68 번:  사후 피임약 구입 방법 69 번:  사후 피임약 성분 70 번:  피임 효과가 있는 경우 71 번:  피임 효과가 없는 경우 72 번:  사전 피임제를 복용 중인 경우
# 73 번:  사후 피임제를 최근 복용한 경우 74 번:  생리 하지 않을 경우 75 번:  생리가 끝나지 않을 경우 76 번:  부정출혈 77 번:  두통, 어지러움, 구토
#
# 질문 =  지금 피임약을 4팩째 먹고 있는데요, 휴약 기후에 8일째 되는 날인 5월 15일에 4팩째 첫알을 밤 9시 35분에 먹고 그다음날인 16일에는 좀 늦게 먹었어요 밤 10시-10시 반 사이에요 근데 그리고 나서 술을 마시고 정확히는 모르겠는데 새벽 1시 50분-2시 10분 사이에 토를 했어요 엄청 많이... 그리고 나서 한 알 더 먹는 거 까먹고 그냥 다음날 17일 밤에 원래 먹던 시간에 약 먹었구요. 확실히 약 먹은 지 세 시간은 지나고 나서 토했는데 약이 흡수가 안 됐을 수도 있나요?.. 그리고 문제는 그 이후에 17일부터 19일까지 피임약은 계속 잘 먹었는데 질 외 사정으로 관계를 여러 번 맺었는데, 혹시 16일 날 먹은 피임약이 흡수가 안 됐으면 아예 하루를 건너뛰고 먹게 된 게 돼서 그 뒤로는 피임 효과가 없나요..? 상세한 설명 부탁드립니다.. 생리 예정일은 6월 8일입니다
# 답변 =  피임약을 복용하다가 충분히 흡수되지 않을 가능성이 있는 구토가 있었기 때문에 효과적인 피임이 이루어지지 않을 가능성도 있기는 합니다. 그러나 보통 피임약 복용 이후 3~4시간 정도가 경과된 경우이고 질 외 사정을 병행한 피임이 적절히 이루어진 경우라면 임신 가능성은 없으므로 피임약을 임의로 중단하지 마시고 꾸준히 스케쥴대로 복용하면 될 것 같습니다. 문의에 참고가 되었기를 바랍니다.
# 질문 요약문을 입력하세요 : x
# last index :  2068
# last index :  2068
